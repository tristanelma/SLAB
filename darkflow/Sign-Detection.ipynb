# %% [markdown]
# # YOLO on Sign Detection with synthetic dataset
#
# __By: Chengyi (Jeff) Chen__

# %%
import pandas as pd

signs = pd.read_csv('signs.csv', low_memory=False)
signs.head(40)
# Out:
#    sign_pk                                            text   latitude  \
# 0        1                                    Lakewood BI        None
# 1        2                       LEFT TURN YIELD ON GREEN        None
# 2        3                                             AL   33.939075
# 3        4                                   BONUS REALTY   33.939354
# 4        5                                         Beogle   33.939424
# 5        6                                            2012       None
# 6        7                                              O        None
# 7        8                                             TR        None
# 8        9                                           ARCO        None
# 9       10                             RESIDENTIAL RENTAL        None
# 10      11                                     JOHN DAVIS   33.939356
# 11      12                            I RENTING 69 . 1367   33.939116
# 12      13                                             ht   33.939104
# 13      14                                     16373531339       None
# 14      15                UORTE INSURANCE 5621 882 - 1007        None
# 15      16                                     LAW OFFICE   33.939354
# 16      17                                       Lakewood        None
# 17      18                                 APPRAISAL WEST        None
# 18      19                                        2017 Go        None
# 19      20  CONSOLIDATION OLIDE SUS DEUDAS - 869 - 1160 :   33.939376
# 20      21                LEASING INFO . 818 - 790 - 1833   33.939354
# 21      22                                          Metro   33.940575
# 22      23                                      Di Cooler        None
# 23      24                                             266  33.940091
# 24      25                                            TES   33.939353
# 25      26                               COLDWELL BANKORO   33.938927
# 26      27                                               2       None
# 27      28                                    SEARTIIKIXC   33.939287
# 28      29                                    2017 notice   33.939247
# 29      30                               10 / 2017 Google        None
# 30      31                                    BROW Coogle   34.086864
# 31      32                                    2017 Google    34.08681
# 32      33                                            9431  34.087074
# 33      34                                     201 Google   34.087245
# 34      35                                        Pacheco   34.103573
# 35      36                                       COMPUTER    34.10371
# 36      37      Jeneration Jewelry Clock • Watch Repair   34.103732
# 37      38                             ATAKAN NAILS & SPA   34.103696
# 38      39                                           euke   34.103573
# 39      40                                 KUZO 18 Google   34.103677
#
#       longitude     languages  \
# 0          None        ['ku']
# 1          None        ['en']
# 2   -118.122228            []
# 3    -118.12207        ['en']
# 4   -118.122016        ['en']
# 5          None        ['pt']
# 6          None        ['pt']
# 7          None            []
# 8          None            []
# 9          None        ['en']
# 10  -118.122065            []
# 11  -118.121641        ['en']
# 12  -118.122215            []
# 13         None            []
# 14         None        ['en']
# 15  -118.122065        ['en']
# 16         None        ['en']
# 17         None        ['en']
# 18         None        ['en']
# 19   -118.12205  ['es', 'en']
# 20  -118.122065        ['en']
# 21  -118.121672        ['en']
# 22         None        ['it']
# 23  -118.121802            []
# 24  -118.122066            []
# 25  -118.122363        ['af']
# 26         None            []
# 27  -118.122087        ['so']
# 28  -118.121861        ['en']
# 29         None        ['en']
# 30  -118.399844        ['en']
# 31  -118.399975        ['en']
# 32  -118.400305            []
# 33  -118.399754        ['en']
# 34  -118.153121        ['es']
# 35  -118.152875        ['en']
# 36  -118.152809        ['en']
# 37  -118.152918        ['id']
# 38  -118.153183        ['nl']
# 39  -118.154104        ['zu']
#
#                                             image_url image_pk sign_heading  \
# 0   https://s3-us-west-1.amazonaws.com/slabgsv-rep...        1   257.059796
# 1   https://s3-us-west-1.amazonaws.com/slabgsv-rep...        1   158.554688
# 2   https://s3-us-west-1.amazonaws.com/slabgsv-rep...        1   211.343149
# 3   https://s3-us-west-1.amazonaws.com/slabgsv-rep...        1     303.2497
# 4   https://s3-us-west-1.amazonaws.com/slabgsv-rep...        1   319.840745
# 5   https://s3-us-west-1.amazonaws.com/slabgsv-rep...        1    78.100962
# 6   https://s3-us-west-1.amazonaws.com/slabgsv-rep...        1     79.33143
# 7   https://s3-us-west-1.amazonaws.com/slabgsv-rep...        1   198.835637
# 8   https://s3-us-west-1.amazonaws.com/slabgsv-rep...        1
# 28  http://138.197.220.71:8889/viewer/overlaySigns/1/    830.0    912.0
# 29  http://138.197.220.71:8889/viewer/overlaySigns/2/    724.0    817.0
# 30  http://138.197.220.71:8889/viewer/overlaySigns/2/   4566.0   4657.0
# 31  http://138.197.220.71:8889/viewer/overlaySigns/2/   5103.0   5184.0
# 32  http://138.197.220.71:8889/viewer/overlaySigns/2/   7080.0   7158.0
# 33  http://138.197.220.71:8889/viewer/overlaySigns/2/  10816.0  10894.0
# 34  http://138.197.220.71:8889/viewer/overlaySigns/3/  11757.0  11833.0
# 35  http://138.197.220.71:8889/viewer/overlaySigns/3/   8229.0   8402.0
# 36  http://138.197.220.71:8889/viewer/overlaySigns/3/   7733.0   7994.0
# 37  http://138.197.220.71:8889/viewer/overlaySigns/3/   8549.0   9076.0
# 38  http://138.197.220.71:8889/viewer/overlaySigns/3/  12229.0  12267.0
# 39  http://138.197.220.71:8889/viewer/overlaySigns/3/    719.0    813.0
#
#         y1      y2
# 0     80.0   137.0
# 1    207.0   269.0
# 2    367.0   447.0
# 3    377.0   439.0
# 4    407.0   427.0
# 5    429.0   447.0
# 6    431.0   448.0
# 7    443.0   454.0
# 8    438.0   482.0
# 9    447.0   489.0
# 10   442.0   477.0
# 11   483.0   542.0
# 12   485.0   514.0
# 13   494.0   536.0
# 14   499.0   539.0
# 15   512.0   535.0
# 16   561.0   581.0
# 17   554.0   596.0
# 18   572.0   590.0
# 19   530.0   607.0
# 20   554.0   596.0
# 21   590.0   612.0
# 22   659.0   679.0
# 23   639.0   666.0
# 24   641.0   679.0
# 25   778.0   800.0
# 26   800.0   813.0
# 27  1014.0  1113.0
# 28  1104.0  1125.0
# 29   571.0   590.0
# 30   676.0   697.0
# 31   797.0   816.0
# 32   780.0   818.0
# 33  1143.0  1161.0
# 34   409.0   422.0
# 35   492.0   580.0
# 36   517.0   617.0
# 37   505.0   601.0
# 38   563.0   578.0
# 39   571.0   590.0

# %%
signs.shape
# Out:
# (423904, 13)

# %% [markdown]
# ---
# ## Last model saved in Checkpoint

# %%
from darkflow.net.build import TFNet
import cv2
import numpy as np
import matplotlib.pyplot as plt

options = {"model": "cfg/tiny-yolo-voc-sign.cfg", 
           "load": -1, 
           "threshold": 0.5}

tfnet = TFNet(options)

imgcv = cv2.imread("./pictures/positive{}.jpg".format(np.random.randint(0, 9999)))
results = tfnet.return_predict(imgcv)
print(results)
# Out:
# Parsing cfg/tiny-yolo-voc-sign.cfg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-829d5d10913c> in <module>()
#       8            "threshold": 0.5}
#       9
# ---> 10 tfnet = TFNet(options)
#      11
#      12 imgcv = cv2.imread("./pictures/positive{}.jpg".format(np.random.randint(0, 9999)))
#
# ~/CAIS++/SLAB/darkflow/darkflow/net/build.py in __init__(self, FLAGS, darknet)
#      56
#      57                 if darknet is None:
# ---> 58                         darknet = Darknet(FLAGS)
#      59                         self.ntrain = len(darknet.layers)
#      60
#
# ~/CAIS++/SLAB/darkflow/darkflow/dark/darknet.py in __init__(self, FLAGS)
#      15
#      16         print('Parsing {}'.format(self.src_cfg))
# ---> 17         src_parsed = self.parse_cfg(self.src_cfg, FLAGS)
#      18         self.src_meta, self.src_layers = src_parsed
#      19
#
# ~/CAIS++/SLAB/darkflow/darkflow/dark/darknet.py in parse_cfg(self, model, FLAGS)
#      66         cfg_layers = cfg_yielder(*args)
#      67         meta = dict(); layers = list()
# ---> 68         for i, info in enumerate(cfg_layers):
#      69             if i == 0: meta = info; continue
#      70             else: new = create_darkop(*info)
#
# ~/CAIS++/SLAB/darkflow/darkflow/utils/process.py in cfg_yielder(model, binary)
#      64         yielding each layer information to initialize `layer`
#      65 	"""
# ---> 66         layers, meta = parser(model); yield meta;
#      67         h, w, c = meta['inp_size']; l = w * h * c
#      68
#
# ~/CAIS++/SLAB/darkflow/darkflow/utils/process.py in parser(model)
#      15                 return l.split('=')[i].strip()
#      16
# ---> 17         with open(model, 'rb') as f:
#      18                 lines = f.readlines()
#      19
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cfg/tiny-yolo-voc-sign.cfg'

# %%
max_confidence = 0
box = None
for x in results:
    if x['confidence'] > max_confidence:
        max_confidence = x['confidence']
        box = x

# %%
max_confidence

# %%
box

# %%
colors = [tuple(255 * np.random.rand(3)) for _ in range(10)]

# %%
for color, result in zip(colors, results):
    tl = (result['topleft']['x'], result['topleft']['y'])
    br = (result['bottomright']['x'], result['bottomright']['y'])
    label = result['label']
    confidence = result['confidence']
    text = '{}: {:.0f}%'.format(label, confidence * 100)
    imgcv = cv2.rectangle(imgcv, tl, br, color, 5)
    imgcv = cv2.putText(imgcv, text, tl, cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 0), 2)
#     cv2.imwrite('./sample_img/out/liquor_out.jpg', imgcv)
    plt.figure(figsize=(8,8))
    plt.imshow(imgcv);

# %% [markdown]
# ## Printing graph saved in .pb file

# %%
import tensorflow as tf
from tensorflow.python.platform import gfile
# GRAPH_PB_PATH = './built_graph/tiny-yolo-voc-liquor.pb'
# with tf.Session() as sess:
#     print("load graph")
#     with gfile.FastGFile(GRAPH_PB_PATH,'rb') as f:
#         graph_def = tf.GraphDef()
#     graph_def.ParseFromString(f.read())
#     sess.graph.as_default()
#     tf.import_graph_def(graph_def, name='')
#     graph_nodes=[n for n in graph_def.node]
#     names = []
#     for t in graph_nodes:
#         names.append(t.name)
#     print(names)

# %% [markdown]
# __Predicting on graph from .pb file__

# %%
def best_prediction():
#     options = {"pbLoad": "./built_graph/tiny-yolo-voc-liquor.pb", 
#                "metaLoad": "./built_graph/tiny-yolo-voc-liquor.meta",
#                "threshold": 0.5}
    
    options = {"model": "cfg/tiny-yolo-voc-sign.cfg", 
               "load": -1,
               "threshold": 0.5}

    tfnet = TFNet(options)

#     imgcv = cv2.imread("./pictures/positive1206.jpg")
    
    imgcv = cv2.imread("./pictures/positive{}.jpg".format(np.random.randint(0, 9999)))
    results = tfnet.return_predict(imgcv)
    
    colors = [tuple(255 * np.random.rand(3)) for _ in range(10)]

    max_confidence = 0
    box = None
    for x in results:
        if x['confidence'] > max_confidence:
            max_confidence = x['confidence']
            box = x
    print(max_confidence)
#     print(results)
    
    tl = (box['topleft']['x'], box['topleft']['y'])
    br = (box['bottomright']['x'], box['bottomright']['y'])
    label = box['label']
    confidence = box['confidence']
    text = '{}: {:.0f}%'.format(label, confidence * 100)
    imgcv = cv2.rectangle(imgcv, tl, br, colors[0], 5)
    imgcv = cv2.putText(imgcv, text, tl, cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 0), 2)
    plt.figure(figsize=(8,8))
    plt.imshow(imgcv);
    
best_prediction()
