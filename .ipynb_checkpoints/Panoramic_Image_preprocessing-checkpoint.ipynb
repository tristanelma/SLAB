# %%
# General Utilities
import re
import os
import sys
import random
import subprocess
from PIL import Image
from PIL import ImageDraw

from tqdm import tqdm

# ML / Deep learning Utilities
import cv2
import numpy as np
from numpy import loadtxt
from pylab import rcParams
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-paper')
# %matplotlib inline

# %%
# Helper function to create a new folder
def mkdir(path):
    try: 
        os.makedirs(path)
    except OSError:
        if not os.path.isdir(path):
            raise
        else:
            print("(%s) already exists" % (path))

# Function to create generator of coordinates
# for small image of window sizes with stride
# stepSize
def sliding_window(image, stepSize, windowSize):
    # slide a window across the image
    for x in range(0, image.shape[1], stepSize):
        for y in range(0, image.shape[0], stepSize):
            yield (x, y, x + windowSize[0], y + windowSize[0])

# %%
# Create directory to store the processed panoramic images
mkdir('./processed_panos')

img = cv2.imread('./liquor_pano.jpg')

# Loop through each sliding window created
for idx, window in tqdm(enumerate(sliding_window(img, 300, (600, 600)))):
    Image.open('./liquor_pano.jpg').crop(window).save('./processed_panos/liquor_pano_{}.jpg'.format(idx), 'JPEG')
# Out:
# 0it [00:00, ?it/s]
# (./processed_panos) already exists
# 225it [00:39,  6.06it/s]

# %%
Image.open('./processed_panos/liquor_pano_1.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600 at 0x12993C2E8>
